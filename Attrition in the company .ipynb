# %% [markdown]
# # Attrition in the company

# %% [markdown]
# ### What Attrition is and what kind of problems it arises within the company?

# %% [markdown]
#  The gradual reduction in the number of employees is called employee attrition. Over time, employee turnover occurs when the workforce size is reduced. That means that the workers are leaving more quickly than they've been hired. Attrition occurs when employees retire, resign, or simply don't get replaced.
#
#  There are various reasons why employees may leave their jobs. These include dissatisfaction with compensation or perks, a dearth of chances for professional growth, and even unfavourable working circumstances.Certain jobs eventually become outdated in a world where the skill sets needed are ever-changing. Not every position is filled in the same formulaic manner when workers depart and a new paradigm of work arises.
#
#  An organisation may face many challenges due to a high rate of attrition. Inadequate institutional knowledge, training gaps, and a lack of continuity are all possible. Positions can take a long time to fill, particularly specialised tasks. If you keep these important positions unfilled, it may become more difficult to fill them in the future.
#
# Your current staff members must take up the slack, and the additional workload may lead to burnout. This decreases overall productivity, which negatively impacts your bottom line and results in disgruntled customers.
#
#  Reduction in workforce is another term for employee attrition in an organisation. Accordingly, attrition may occur voluntarily or involuntarily.Employee attrition can be a concern since it frequently results in a decline in talent within the organisation and the workforce as a whole.
#
# The purpose of this analysis is to determine the reasons behind employees' voluntary departures and any barriers that may have kept them from quitting.

# %% [markdown]
# ### Exploratory data analysis
#
# - Find patterns within the data by using visualization tools
# - Check the data for missing values and describe the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
from plotly.offline import init_notebook_mode
from plotly.subplots import make_subplots
import seaborn as sns
import datetime as dt
import warnings

# %%
df = pd.read_csv("Employee-Attrition.csv")

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.head(10)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
# 8   38        No  Travel_Frequently        216  Research & Development
# 9   36        No      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
# 5                 2          2  Life Sciences              1               8
# 6                 3          3        Medical              1              10
# 7                24          1  Life Sciences              1              11
# 8                23          3  Life Sciences              1              12
# 9                27          3        Medical              1              13
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
# 5  ...                         3            80                 0
# 6  ...                         1            80                 3
# 7  ...                         2            80                 1
# 8  ...                         2            80                 0
# 9  ...                         2            80                 2
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
# 5                  8                      2               2               7
# 6                 12                      3               2               1
# 7                  1                      2               3               1
# 8                 10                      2               3               9
# 9                 17                      3               2               7
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
# 5                  7                        3                     6
# 6                  0                        0                     0
# 7                  0                        0                     0
# 8                  7                        1                     8
# 9                  7                        7                     7
#
# [10 rows x 35 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   object
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(26), object(9)
# memory usage: 402.1+ KB

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# After use of heatmap and .isnull().sum() we are sure there are no missing values.

# %%
df.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# TotalWorkingYears             40
# TrainingTimesLastYear          7
# WorkLifeBalance                4
# YearsAtCompany                37
# YearsInCurrentRole            19
# YearsSinceLastPromotion       16
# YearsWithCurrManager          18
# dtype: int64

# %% [markdown]
# As you can see there are features with only one value. We have no use of constant features with singular result so I will drop them to reduce size of columns we work with.

# %%
df.drop(columns=["EmployeeCount", "Over18", "StandardHours"], inplace=True)

# %%
df.shape
# Out:
# (1470, 32)

# %% [markdown]
# ### Summary of categorical variables

# %%
categorical = df.select_dtypes(include=object).columns.tolist()
cat_df = pd.DataFrame(df[categorical].melt(var_name='column', value_name='value')
                    .value_counts()).rename(columns={0: 'count'}).sort_values(by=['column', 'count'])
display(df.select_dtypes(include=object).describe())
display(cat_df)
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus OverTime
# count              1470          1470     1470
# unique                9             3        2
# top     Sales Executive       Married       No
# freq                326           673     1054
#                                           count
# column         value
# Attrition      Yes                          237
#                No                          1233
# BusinessTravel Non-Travel                   150
#                Travel_Frequently            277
#                Travel_Rarely               1043
# Department     Human Resources               63
#                Sales                        446
#                Research & Development       961
# EducationField Human Resources               27
#                Other                         82
#                Technical Degree             132
#                Marketing                    159
#                Medical                      464
#                Life Sciences                606
# Gender         Female                       588
#                Male                         882
# JobRole        Human Resources               52
#                Research Director             80
#                Sales Representative          83
#                Manager                      102
#                Healthcare Representative    131
#                Manufacturing Director       145
#                Laboratory Technician        259
#                Research Scientist           292
#                Sales Executive              326
# MaritalStatus  Divorced                     327
#                Single                       470
#                Married                      673
# OverTime       Yes                          416
#                No                          1054

# %% [markdown]
# #### By looking at the values of Attrition we can calclulate turnover rate of employees in the company. It is set to 16.12%.

# %% [markdown]
# ### Summary of numerical variables

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810   802.485714          9.192517     2.912925
# std       9.135373   403.509100          8.106864     1.024165
# min      18.000000   102.000000          1.000000     1.000000
# 25%      30.000000   465.000000          2.000000     2.000000
# 50%      36.000000   802.000000          7.000000     3.000000
# 75%      43.000000  1157.000000         14.000000     4.000000
# max      60.000000  1499.000000         29.000000     5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# std        602.024335                 1.093082    20.329428        0.711561
# min          1.000000                 1.000000    30.000000        1.000000
# 25%        491.250000                 2.000000    48.000000        2.000000
# 50%       1020.500000                 3.000000    66.000000        3.000000
# 75%       1555.750000                 4.000000    83.750000        3.000000
# max       2068.000000                 4.000000   100.000000        4.000000
#
#           JobLevel  JobSatisfaction  ...  PerformanceRating  \
# count  1470.000000      1470.000000  ...        1470.000000
# mean      2.063946         2.728571  ...           3.153741
# std       1.106940         1.102846  ...           0.360824
# min       1.000000         1.000000  ...           3.000000
# 25%       1.000000         2.000000  ...           3.000000
# 50%       2.000000         3.000000  ...           3.000000
# 75%       3.000000         4.000000  ...           3.000000
# max       5.000000         4.000000  ...           4.000000
#
#        RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# count               1470.000000       1470.000000        1470.000000
# mean                   2.712245          0.793878          11.279592
# std                    1.081209          0.852077           7.780782
# min                    1.000000          0.000000           0.000000
# 25%                    2.000000          0.000000           6.000000
# 50%                    3.000000          1.000000          10.000000
# 75%                    4.000000          1.000000          15.000000
# max                    4.000000          3.000000          40.000000
#
#        TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# count            1470.000000      1470.000000     1470.000000
# mean                2.799320         2.761224        7.008163
# std                 1.289271         0.706476        6.126525
# min                 0.000000         1.000000        0.000000
# 25%                 2.000000         2.000000        3.000000
# 50%                 3.000000         3.000000        5.000000
# 75%                 3.000000         3.000000        9.000000
# max                 6.000000         4.000000       40.000000
#
#        YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# count         1470.000000              1470.000000           1470.000000
# mean             4.229252                 2.187755              4.123129
# std              3.623137                 3.222430              3.568136
# min              0.000000                 0.000000              0.000000
# 25%              2.000000                 0.000000              2.000000
# 50%              3.000000                 1.000000              3.000000
# 75%              7.000000                 3.000000              7.000000
# max             18.000000                15.000000             17.000000
#
# [8 rows x 24 columns]

# %% [markdown]
# ### Q1.  How is Attrition distributed over Departments?

# %%
df["Department"].unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
sns.displot(df, x="Department", hue="Attrition", palette={"Yes": "red", "No": "blue"}, aspect=2.5, bins=50)

# %% [markdown]
# Above we can see the distribution of attrition values in each department. The highest number of them is in Research and Development.

# %%
sales_df = df[df["Department"] == "Sales"]
hr_df = df[df["Department"] == "Human Resources"]

# %%
sns.displot(sales_df, x="Department", hue="Attrition", palette={"Yes": "red", "No": "blue"}, aspect=2.5, bins=50)

# %%
sns.displot(hr_df, x="Department", hue="Attrition", palette={"Yes": "red", "No": "blue"}, aspect=2.5, bins=50)

# %% [markdown]
# The sales department has the highest percentage of total values with positive Attrition compared to the other two departments.

# %% [markdown]
# ### Q2. How is attrition distributed over gender?

# %%
sns.displot(df, x="Gender", hue="Attrition", palette={"Yes": "red", "No": "blue"}, aspect=2.5, bins=50)

# %% [markdown]
# ### Q3. Does working over time affects attrition rate?

# %%
sns.displot(df, x="OverTime", hue="Department", palette={"Yes": "red", "No": "blue"}, aspect=2.5, bins=50)

# %% [markdown]
# We can see that significant number of employees that worked overtime have left the company.

# %% [markdown]
# ### Q4. Does Job Role affect attrition and if yes how?

# %%
sns.displot(df, x="JobRole", hue="Attrition", palette={"Yes": "red", "No": "blue"}, aspect=3.6, bins=50)

# %% [markdown]
# #### * We can see above that compared to total count of values, job role Sales representative have highest percantage of employees that left. That indicates a higher than average attrition rate in that job role.

# %% [markdown]
# ### Q5. How are JobRoles distributed over departments?

# %%
sns.displot(df, x="JobRole", hue="Department", palette={"Human Resources": "red", "Sales": "blue", "Research & Development": "green"}, aspect=3.6, bins=50)

# %% [markdown]
# Research & Development have highest number of job roles compared to Sales and Human Resources departments.

# %% [markdown]
# Let's find out what is the main reason of people leaving position of sales representative. But before that find exact percantage of people that left Sales Representative position.

# %%
sales_rep_df = df[df['JobRole'] == 'Sales Representative']

# %%
attrition_counts = sales_rep_df['Attrition'].value_counts()

# %%
plt.figure(figsize=(10, 6))
plt.pie(attrition_counts, labels=attrition_counts.index, autopct='%1.1f%%', colors=['orange', 'blue'])
plt.title('Attrition for Sales Representatives')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Q6. Does Age affect attrition in Job Role of Sales Representatives?

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x="Attrition", y="Age", data=sales_rep_df, palette={"Yes": "red", "No": "blue"})
plt.title('Age Distribution of Sales Representatives by Attrition Status')
plt.show()

# %% [markdown]
# The most of people that leave Sale Representative positon are in group between 21 and 31 years of age.

# %% [markdown]
# ### Q7. How does education level affects attrition for Sales Representatives?

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x="Attrition", y="Education", data=sales_rep_df, palette={"Yes": "red", "No": "blue"})
plt.title('Education Level Distribution of Sales Representatives by Attrition Status')
plt.show()

# %% [markdown]
# -  Individuals with __medium level of education tend to leave the most__.
# -  So far we have very useful insights based on simple visual representation of Education Level and Age.
# -  To find out more about job satisfaction we can vusualize attrition over DailyRate, OverTime, Marital status and DistanceFromHome.
# -  With these insights we can make informed decisions and know what exactly causes people to leave Sales representative Job Role.
